# %% [markdown]
# preparing labels and imagery for use with tensorflow

# %%
# takes a set of images and labels and prepares a structure that can be fed into
# inception v3 (which can handle imagenet 2012 inputs)
# this involves
# finding the coordinates of labelled points and the corresponding image
#  cropping at most 299 x 299 pixels around each labeled point.
# storing each cropped image in directories named after the type of label
import pandas as pd
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import string
import glob

# %matplotlib inline
# Out:
# /Users/opizarro/.virtualenvs/keras/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
#training_path = '/Users/opizarro/training_data/max-woodside'
training_path = '/Volumes/LZD1601/training_data/benthoz_299patch'

def maybe_makedir(dirname, force=False):
  if os.path.isdir(dirname) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping making dir' % (dirname))
  else:
    print('Making dir %s.' % dirname)
    os.makedirs(dirname)
  return 

maybe_makedir(training_path)
# Out:
# /Volumes/LZD1601/training_data/benthoz_299patch already present - Skipping making dir

# %%
def save_patch(crop_image,imagename,x,y,halfsize,imlabel,training_path):
    # save cropped image in corresponding directory
    crop_name = imagename + '_' + str(x) + '_' + str(y) + '_' + str(halfsize) + '.jpg'
    fullcrop_name = os.path.join(training_path,imlabel,crop_name)
    cv2.imwrite(fullcrop_name,crop_image)

def save_patch_4rot(crop_image,imagename,x,y,halfsize,imlabel,training_path):
    
    (h, w) = crop_image.shape[:2]
    center = (w / 2, h / 2)
    
    angles = [0,90,180,270]
    for angle in angles:
        M = cv2.getRotationMatrix2D(center, angle, 1.0)
        rotated = cv2.warpAffine(crop_image, M, (w, h))
        save_patch(rotated,imagename+'_'+str(angle),x,y,halfsize,imlabel,training_path)

# %%
#survey_sheet = '/Users/opizarro/max-woodside/QN01/MSA157-40_QN01.xls'
#images_location = '/Users/opizarro/max-woodside/QN01/Stations'

def process_sheet(survey_sheet, images_location):
    #df = pd.read_excel(survey_sheet)
    df = pd.read_csv(survey_sheet)
    df.head()
    
#df.columns

#for each row, 
#1)make a directory using Species label (if it doesn't exist already),
#2)cut out the part of the image that corresponds to a 299x299 (at most) window around the X Y coords
#3)save the cropped inmage into the corresponding directory
    class_label_set = set(df['code'])
    print class_label_set
    class_label_list = list(class_label_set)
    print('Number of classes %i') % len(class_label_list)
    print('Testing...')
    for imclass in class_label_list:
        #imclasses = string.split(imclass,':')
        #imclass_short = imclasses[0]
        #print('*** imclass %s shortened to %s') % (imclass, imclass_short)
        print('*** imclass %s') % imclass
        maybe_makedir(os.path.join(training_path, imclass))
    
    image_set = set(df['web_location'])
    xdim = 1360
    ydim = 1024
    patchsize = 299
    halfsize = int((patchsize-1)/2)
    padsize = halfsize
    image_list = list(image_set)
    print("Number of images %i, number of entries %i") % (len(image_list),len(df['web_location']))

    prior_imagename = ''
    
    for row in df.iterrows():
    #print(row[1])
    # read image
        imagename = os.path.basename(row[1].web_location)
        fullimagename = os.path.join(images_location,imagename)
        if os.path.isfile(fullimagename):
            #print('reading %s') % fullimagename
            if fullimagename != prior_imagename:
                # only read image if its a different one from the one we've been using
                image = cv2.imread(os.path.join(images_location,imagename))
                
                # pad image with reflected data
                reflect101 = cv2.copyMakeBorder(image,padsize,padsize,padsize,padsize,cv2.BORDER_REFLECT_101)
                
                #print('image shape %i %i %i') % image.shape
                prior_imagename = fullimagename
        
    
            #cv2.imshow("original",image)
            #plt.figure(1)
            #plt.imshow(image)
            # read label
            #print('row label %s') % row[1].code
            #imlabels = string.split(row[1].name,':')
            #imlabel = imlabels[0]
            imlabel = row[1].code
            #print ('entry %s has label %s') % (imagename, imlabel)
   
   
            # find centre points and add padding offset
            x = int(round(row[1].x*xdim + padsize))
            y = int(round(row[1].y*ydim + padsize))
        
         
            #print('x %i, y %i, xdim %i, ydim %i') % (x,y,xdim,ydim)
            # check dimensions correpond
            if xdim != image.shape[1] or ydim !=image.shape[0]:
                print('WARNING: actual image size and size in database not consistent')
    
    
            # draw circle
            #cv2.circle(image,(x,y),11,(0,255,0),-1)
    
            # crop around centre point - with padding this shouldn't be necessary
            #dx = min(min(x,halfsize),min(halfsize,xdim+padsize-x));
            #dy = min(min(y,halfsize),min(halfsize,ydim+padsize-y));
            #hs = int(min(dx,dy))
            hs = halfsize
            # check that padding worked
            #print hs, x, y 
            if hs == halfsize : 
                
                crop_image = reflect101[y-hs:y+hs, x-hs:x+hs]
        
                # generate rotated versions
                # save with unique name
                #save_patch_4rot(crop_image,imagename,x,y,halfsize,imlabel,training_path)
                save_patch(crop_image,imagename,x,y,halfsize,imlabel,training_path)
                #crop_im_fliplr = cv2.flip(crop_image,1)
                #save_patch_4rot(crop_im_fliplr,imagename+'_lr',x,y,halfsize,imlabel,training_path)
                  
    
                if 0 and imlabel != 'Sand' and imlabel != 'Turf':
                    cutstr =  ('this dot %s has label %s') % (imagename, imlabel)
                    titstr =  ('x %i, y %i, xdim %i, ydim %i, hs %i') % (x,y,xdim,ydim,hs)
                    plt.figure(1)
                    plt.imshow(image)
                    plt.title(titstr)
                    plt.figure(2)
                    plt.imshow(crop_image)
                    plt.title(cutstr)
        
                if row[0]%100 == 0:
                    print("processing entry " + str(row[0]) + "\r")
            else:
                print("**** WARNING: padding problem at x=%i, y=%i on %s") % (x,y,fullimagename)
        else:
            if row[0]%100 == 0:
                    print("processing entry " + str(row[0]) + "\r")
                    print('**** WARNING: could not find image %s') % fullimagename

# %%
# each campaign folder in benthoz2015 has a cvs file and the related images

base_location = '/Volumes/LZD1601/benthoz2015'

campaign_list=os.listdir(base_location)
for campaign in campaign_list:
    #if ("W") in campaign:
    print("processing campaign {}".format(campaign))
    full_campaign=os.path.join(base_location,campaign)
    if os.path.isdir(full_campaign):
        image_sheet=glob.glob(os.path.join(full_campaign,'*.csv'))
        print os.path.join(full_campaign,'*.csv')
        if len(image_sheet)>0:
            process_sheet(image_sheet[0], full_campaign)
        else:
            print('no csv found in %s') % campaign
    else:
        print('%s is not a folder') % campaign
    #else:
    #    print("not processing campaign {}".format(campaign))
# Out:
# processing campaign BENTHOZ-2015-imagelist.csv
# BENTHOZ-2015-imagelist.csv is not a folder
# processing campaign ._BENTHOZ-2015-imagelist.csv
# ._BENTHOZ-2015-imagelist.csv is not a folder
# processing campaign PS201012
# /Volumes/LZD1601/benthoz2015/PS201012/*.csv
# set(['CBOM', 'WA', 'BM', 'MAFR', 'MAEFB', 'MAFB', 'MAFG', 'CBFR', 'MALCB', 'SPH', 'SPM', 'CBBFA', 'SPC', 'SPE', 'MALCEK', 'MAAR', 'BIOTA', 'MAAG', 'MAS', 'SPES', 'SPEP', 'MAA', 'SPEL', 'SPMR', 'MAF', 'SPEB', 'CBNBU', 'SP', 'CRB', 'CSBRPD', 'MALAR', 'SCC', 'SCB', 'MALAB', 'MAEFR', 'MALA', 'CSE', 'CSF', 'CNCAC', 'S', 'CNCAZ', 'CBB', 'MA', 'CBE', 'BRYSF', 'CNTR', 'SPHT', 'SUP', 'SPHC', 'ASS', 'BRYH', 'MASB', 'ASC', 'WPO', 'MASR', 'BRYS', 'AUC', 'MAENG', 'MAENB', 'CNCA', 'AUS', 'MAENR', 'CS', 'UNK', 'MAEC', 'BRY', 'MAEF', 'CNHYD', 'CNHYC', 'SU', 'MAEN', 'CBBNA', 'BRYHF', 'SC', 'BRYHM', 'UNS', 'A', 'ESU', 'ESS', 'AS', 'AU', 'ESUR', 'SPMSI', 'MAECR', 'MAECB', 'MOCH'])
# Number of classes 86
# Testing...
# *** imclass CBOM
# /Volumes/LZD1601/training_data/benthoz_299patch/CBOM already present - Skipping making dir
# *** imclass WA
# /Volumes/LZD1601/training_data/benthoz_299patch/WA already present - Skipping making dir
# *** imclass BM
# /Volumes/LZD1601/training_data/benthoz_299patch/BM already present - Skipping making dir
# *** imclass MAFR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFR already present - Skipping making dir
# *** imclass MAEFB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEFB already present - Skipping making dir
# *** imclass MAFB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFB already present - Skipping making dir
# *** imclass MAFG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFG already present - Skipping making dir
# *** imclass CBFR
# /Volumes/LZD1601/training_data/benthoz_299patch/CBFR already present - Skipping making dir
# *** imclass MALCB
# /Volumes/LZD1601/training_data/benthoz_299patch/MALCB already present - Skipping making dir
# *** imclass SPH
# /Volumes/LZD1601/training_data/benthoz_299patch/SPH already present - Skipping making dir
# *** imclass SPM
# /Volumes/LZD1601/training_data/benthoz_299patch/SPM already present - Skipping making dir
# *** imclass CBBFA
# /Volumes/LZD1601/training_data/benthoz_299patch/CBBFA already present - Skipping making dir
# *** imclass SPC
# /Volumes/LZD1601/training_data/benthoz_299patch/SPC already present - Skipping making dir
# *** imclass SPE
# /Volumes/LZD1601/training_data/benthoz_299patch/SPE already present - Skipping making dir
# *** imclass MALCEK
# /Volumes/LZD1601/training_data/benthoz_299patch/MALCEK already present - Skipping making dir
# *** imclass MAAR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAAR already present - Skipping making dir
# *** imclass BIOTA
# /Volumes/LZD1601/training_data/benthoz_299patch/BIOTA already present - Skipping making dir
# *** imclass MAAG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAAG already present - Skipping making dir
# *** imclass MAS
# /Volumes/LZD1601/training_data/benthoz_299patch/MAS already present - Skipping making dir
# *** imclass SPES
# /Volumes/LZD1601/training_data/benthoz_299patch/SPES already present - Skipping making dir
# *** imclass SPEP
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEP already present - Skipping making dir
# *** imclass MAA
# /Volumes/LZD1601/training_data/benthoz_299patch/MAA already present - Skipping making dir
# *** imclass SPEL
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEL already present - Skipping making dir
# *** imclass SPMR
# /Volumes/LZD1601/training_data/benthoz_299patch/SPMR already present - Skipping making dir
# *** imclass MAF
# /Volumes/LZD1601/training_data/benthoz_299patch/MAF already present - Skipping making dir
# *** imclass SPEB
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEB already present - Skipping making dir
# *** imclass CBNBU
# /Volumes/LZD1601/training_data/benthoz_299patch/CBNBU already present - Skipping making dir
# *** imclass SP
# /Volumes/LZD1601/training_data/benthoz_299patch/SP already present - Skipping making dir
# *** imclass CRB
# /Volumes/LZD1601/training_data/benthoz_299patch/CRB already present - Skipping making dir
# *** imclass CSBRPD
# /Volumes/LZD1601/training_data/benthoz_299patch/CSBRPD already present - Skipping making dir
# *** imclass MALAR
# /Volumes/LZD1601/training_data/benthoz_299patch/MALAR already present - Skipping making dir
# *** imclass SCC
# /Volumes/LZD1601/training_data/benthoz_299patch/SCC already present - Skipping making dir
# *** imclass SCB
# /Volumes/LZD1601/training_data/benthoz_299patch/SCB already present - Skipping making dir
# *** imclass MALAB
# /Volumes/LZD1601/training_data/benthoz_299patch/MALAB already present - Skipping making dir
# *** imclass MAEFR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEFR already present - Skipping making dir
# *** imclass MALA
# /Volumes/LZD1601/training_data/benthoz_299patch/MALA already present - Skipping making dir
# *** imclass CSE
# /Volumes/LZD1601/training_data/benthoz_299patch/CSE already present - Skipping making dir
# *** imclass CSF
# /Volumes/LZD1601/training_data/benthoz_299patch/CSF already present - Skipping making dir
# *** imclass CNCAC
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCAC already present - Skipping making dir
# *** imclass S
# /Volumes/LZD1601/training_data/benthoz_299patch/S already present - Skipping making dir
# *** imclass CNCAZ
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCAZ already present - Skipping making dir
# *** imclass CBB
# /Volumes/LZD1601/training_data/benthoz_299patch/CBB already present - Skipping making dir
# *** imclass MA
# /Volumes/LZD1601/training_data/benthoz_299patch/MA already present - Skipping making dir
# *** imclass CBE
# /Volumes/LZD1601/training_data/benthoz_299patch/CBE already present - Skipping making dir
# *** imclass BRYSF
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYSF already present - Skipping making dir
# *** imclass CNTR
# /Volumes/LZD1601/training_data/benthoz_299patch/CNTR already present - Skipping making dir
# *** imclass SPHT
# /Volumes/LZD1601/training_data/benthoz_299patch/SPHT already present - Skipping making dir
# *** imclass SUP
# /Volumes/LZD1601/training_data/benthoz_299patch/SUP already present - Skipping making dir
# *** imclass SPHC
# /Volumes/LZD1601/training_data/benthoz_299patch/SPHC already present - Skipping making dir
# *** imclass ASS
# /Volumes/LZD1601/training_data/benthoz_299patch/ASS already present - Skipping making dir
# *** imclass BRYH
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYH already present - Skipping making dir
# *** imclass MASB
# /Volumes/LZD1601/training_data/benthoz_299patch/MASB already present - Skipping making dir
# *** imclass ASC
# /Volumes/LZD1601/training_data/benthoz_299patch/ASC already present - Skipping making dir
# *** imclass WPO
# /Volumes/LZD1601/training_data/benthoz_299patch/WPO already present - Skipping making dir
# *** imclass MASR
# /Volumes/LZD1601/training_data/benthoz_299patch/MASR already present - Skipping making dir
# *** imclass BRYS
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYS already present - Skipping making dir
# *** imclass AUC
# /Volumes/LZD1601/training_data/benthoz_299patch/AUC already present - Skipping making dir
# *** imclass MAENG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENG already present - Skipping making dir
# *** imclass MAENB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENB already present - Skipping making dir
# *** imclass CNCA
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCA already present - Skipping making dir
# *** imclass AUS
# /Volumes/LZD1601/training_data/benthoz_299patch/AUS already present - Skipping making dir
# *** imclass MAENR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENR already present - Skipping making dir
# *** imclass CS
# /Volumes/LZD1601/training_data/benthoz_299patch/CS already present - Skipping making dir
# *** imclass UNK
# /Volumes/LZD1601/training_data/benthoz_299patch/UNK already present - Skipping making dir
# *** imclass MAEC
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEC already present - Skipping making dir
# *** imclass BRY
# /Volumes/LZD1601/training_data/benthoz_299patch/BRY already present - Skipping making dir
# *** imclass MAEF
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEF already present - Skipping making dir
# *** imclass CNHYD
# /Volumes/LZD1601/training_data/benthoz_299patch/CNHYD already present - Skipping making dir
# *** imclass CNHYC
# /Volumes/LZD1601/training_data/benthoz_299patch/CNHYC already present - Skipping making dir
# *** imclass SU
# /Volumes/LZD1601/training_data/benthoz_299patch/SU already present - Skipping making dir
# *** imclass MAEN
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEN already present - Skipping making dir
# *** imclass CBBNA
# /Volumes/LZD1601/training_data/benthoz_299patch/CBBNA already present - Skipping making dir
# *** imclass BRYHF
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYHF already present - Skipping making dir
# *** imclass SC
# /Volumes/LZD1601/training_data/benthoz_299patch/SC already present - Skipping making dir
# *** imclass BRYHM
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYHM already present - Skipping making dir
# *** imclass UNS
# /Volumes/LZD1601/training_data/benthoz_299patch/UNS already present - Skipping making dir
# *** imclass A
# /Volumes/LZD1601/training_data/benthoz_299patch/A already present - Skipping making dir
# *** imclass ESU
# /Volumes/LZD1601/training_data/benthoz_299patch/ESU already present - Skipping making dir
# *** imclass ESS
# /Volumes/LZD1601/training_data/benthoz_299patch/ESS already present - Skipping making dir
# *** imclass AS
# /Volumes/LZD1601/training_data/benthoz_299patch/AS already present - Skipping making dir
# *** imclass AU
# /Volumes/LZD1601/training_data/benthoz_299patch/AU already present - Skipping making dir
# *** imclass ESUR
# /Volumes/LZD1601/training_data/benthoz_299patch/ESUR already present - Skipping making dir
# *** imclass SPMSI
# /Volumes/LZD1601/training_data/benthoz_299patch/SPMSI already present - Skipping making dir
# *** imclass MAECR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECR already present - Skipping making dir
# *** imclass MAECB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECB already present - Skipping making dir
# *** imclass MOCH
# /Volumes/LZD1601/training_data/benthoz_299patch/MOCH already present - Skipping making dir
# Number of images 939, number of entries 23475
# processing entry 0
# processing entry 100
# processing entry 200
# processing entry 300
# processing entry 400
# processing entry 500
# processing entry 600
# processing entry 700
# processing entry 800
# processing entry 900
# processing entry 1000
# processing entry 1100
# processing entry 1200
# processing entry 1300
# processing entry 1400
# processing entry 1500
# processing entry 1600
# processing entry 1700
# processing entry 1800
# processing entry 1900
# processing entry 2000
# processing entry 2100
# processing entry 2200
# processing entry 2300
# processing entry 2400
# processing entry 2500
# processing entry 2600
# processing entry 2700
# processing entry 2800
# processing entry 2900
# processing entry 3000
# processing entry 3100
# processing entry 3200
# processing entry 3300
# processing entry 3400
# processing entry 3500
# processing entry 3600
# processing entry 3700
# processing entry 3800
# processing entry 3900
# processing entry 4000
# processing entry 4100
# processing entry 4200
# processing entry 4300
# processing entry 4400
# processing entry 4500
# processing entry 4600
# processing entry 4700
# processing entry 4800
# processing entry 4900
# processing entry 5000
# processing entry 5100
# processing entry 5200
# processing entry 5300
# processing entry 5400
# processing entry 5500
# processing entry 5600
# processing entry 5700
# processing entry 5800
# processing entry 5900
# processing entry 6000
# processing entry 6100
# processing entry 6200
# processing entry 6300
# processing entry 6400
# processing entry 6500
# processing entry 6600
# processing entry 6700
# processing entry 6800
# processing entry 6900
# processing entry 7000
# processing entry 7100
# processing entry 7200
# processing entry 7300
# processing entry 7400
# processing entry 7500
# processing entry 7600
# processing entry 7700
# processing entry 7800
# processing entry 7900
# processing entry 8000
# processing entry 8100
# processing entry 8200
# processing entry 8300
# processing entry 8400
# processing entry 8500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_224730_573_LC16.png
# processing entry 8600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_205522_985_LC16.png
# processing entry 8700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_205629_995_LC16.png
# processing entry 8800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_225345_598_LC16.png
# processing entry 8900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_225605_602_LC16.png
# processing entry 9000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_210208_981_LC16.png
# processing entry 9100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_225935_617_LC16.png
# processing entry 9200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_230027_581_LC16.png
# processing entry 9300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_230144_624_LC16.png
# processing entry 9400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_230328_624_LC16.png
# processing entry 9500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_230524_599_LC16.png
# processing entry 9600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_211044_011_LC16.png
# processing entry 9700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_230752_600_LC16.png
# processing entry 9800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_211349_018_LC16.png
# processing entry 9900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_211459_995_LC16.png
# processing entry 10000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_211604_999_LC16.png
# processing entry 10100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_211721_990_LC16.png
# processing entry 10200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_231520_629_LC16.png
# processing entry 10300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_231722_584_LC16.png
# processing entry 10400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_212249_992_LC16.png
# processing entry 10500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_231944_604_LC16.png
# processing entry 10600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_212443_010_LC16.png
# processing entry 10700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_212624_997_LC16.png
# processing entry 10800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_212752_999_LC16.png
# processing entry 10900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101119_212920_014_LC16.png
# processing entry 11000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_223157_614_LC16.png
# processing entry 11100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_190214_645_LC16.png
# processing entry 11200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_223344_598_LC16.png
# processing entry 11300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_190427_637_LC16.png
# processing entry 11400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_193005_767_LC16.png
# processing entry 11500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_193040_770_LC16.png
# processing entry 11600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_223647_604_LC16.png
# processing entry 11700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_223746_606_LC16.png
# processing entry 11800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_193308_784_LC16.png
# processing entry 11900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_063801_710_LC16.png
# processing entry 12000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_032632_643_LC16.png
# processing entry 12100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_191010_636_LC16.png
# processing entry 12200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_032836_633_LC16.png
# processing entry 12300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064101_748_LC16.png
# processing entry 12400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_224246_621_LC16.png
# processing entry 12500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_032935_643_LC16.png
# processing entry 12600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064155_719_LC16.png
# processing entry 12700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_191311_628_LC16.png
# processing entry 12800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_193913_777_LC16.png
# processing entry 12900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064335_763_LC16.png
# processing entry 13000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_194030_778_LC16.png
# processing entry 13100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_191546_655_LC16.png
# processing entry 13200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064523_723_LC16.png
# processing entry 13300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_033410_632_LC16.png
# processing entry 13400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_194239_772_LC16.png
# processing entry 13500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064749_732_LC16.png
# processing entry 13600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064845_756_LC16.png
# processing entry 13700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_064905_720_LC16.png
# processing entry 13800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_192015_638_LC16.png
# processing entry 13900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_225123_636_LC16.png
# processing entry 14000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_192037_650_LC16.png
# processing entry 14100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_033826_636_LC16.png
# processing entry 14200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_194657_781_LC16.png
# processing entry 14300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_225345_623_LC16.png
# processing entry 14400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_034040_684_LC16.png
# processing entry 14500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_194917_769_LC16.png
# processing entry 14600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_225553_624_LC16.png
# processing entry 14700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_225718_658_LC16.png
# processing entry 14800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_192658_660_LC16.png
# processing entry 14900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_195303_776_LC16.png
# processing entry 15000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_192826_645_LC16.png
# processing entry 15100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_065807_751_LC16.png
# processing entry 15200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_065859_739_LC16.png
# processing entry 15300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_230108_623_LC16.png
# processing entry 15400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_034809_667_LC16.png
# processing entry 15500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_230233_614_LC16.png
# processing entry 15600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_230358_631_LC16.png
# processing entry 15700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_035055_662_LC16.png
# processing entry 15800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_230524_649_LC16.png
# processing entry 15900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_200038_777_LC16.png
# processing entry 16000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_200121_787_LC16.png
# processing entry 16100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_070546_744_LC16.png
# processing entry 16200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_070731_751_LC16.png
# processing entry 16300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_035543_689_LC16.png
# processing entry 16400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_193934_692_LC16.png
# processing entry 16500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_070916_757_LC16.png
# processing entry 16600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_194108_657_LC16.png
# processing entry 16700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_035841_675_LC16.png
# processing entry 16800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_040020_659_LC16.png
# processing entry 16900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_194342_694_LC16.png
# processing entry 17000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_071340_783_LC16.png
# processing entry 17100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_040531_671_LC16.png
# processing entry 17200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101121_040717_685_LC16.png
# processing entry 17300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_232230_639_LC16.png
# processing entry 17400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_195314_673_LC16.png
# processing entry 17500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_232455_617_LC16.png
# processing entry 17600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_195450_657_LC16.png
# processing entry 17700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_202125_782_LC16.png
# processing entry 17800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_195651_681_LC16.png
# processing entry 17900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_202315_803_LC16.png
# processing entry 18000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_013245_165_LC16.png
# processing entry 18100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_232928_622_LC16.png
# processing entry 18200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_233004_636_LC16.png
# processing entry 18300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_233044_636_LC16.png
# processing entry 18400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_202651_831_LC16.png
# processing entry 18500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_013617_170_LC16.png
# processing entry 18600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_202759_791_LC16.png
# processing entry 18700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_233354_631_LC16.png
# processing entry 18800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_013906_200_LC16.png
# processing entry 18900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_233610_632_LC16.png
# processing entry 19000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_203201_800_LC16.png
# processing entry 19100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_014155_208_LC16.png
# processing entry 19200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_203316_810_LC16.png
# processing entry 19300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_200806_706_LC16.png
# processing entry 19400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_014311_165_LC16.png
# processing entry 19500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_234003_637_LC16.png
# processing entry 19600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_014432_190_LC16.png
# processing entry 19700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_014514_176_LC16.png
# processing entry 19800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_201120_668_LC16.png
# processing entry 19900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_203734_803_LC16.png
# processing entry 20000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_203802_830_LC16.png
# processing entry 20100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_014809_174_LC16.png
# processing entry 20200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_203942_804_LC16.png
# processing entry 20300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_204031_810_LC16.png
# processing entry 20400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_015021_172_LC16.png
# processing entry 20500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_204309_799_LC16.png
# processing entry 20600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_234910_651_LC16.png
# processing entry 20700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_235119_629_LC16.png
# processing entry 20800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_202037_678_LC16.png
# processing entry 20900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_202157_679_LC16.png
# processing entry 21000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_202300_676_LC16.png
# processing entry 21100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_235503_637_LC16.png
# processing entry 21200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101122_202436_701_LC16.png
# processing entry 21300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_020030_183_LC16.png
# processing entry 21400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205144_805_LC16.png
# processing entry 21500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205221_796_LC16.png
# processing entry 21600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205246_799_LC16.png
# processing entry 21700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_235911_632_LC16.png
# processing entry 21800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_235936_635_LC16.png
# processing entry 21900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_020435_218_LC16.png
# processing entry 22000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205623_818_LC16.png
# processing entry 22100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205748_821_LC16.png
# processing entry 22200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_205840_825_LC16.png
# processing entry 22300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_022633_977_LC16.png
# processing entry 22400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_022910_939_LC16.png
# processing entry 22500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_023127_943_LC16.png
# processing entry 22600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_023610_929_LC16.png
# processing entry 22700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_023855_946_LC16.png
# processing entry 22800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_024220_938_LC16.png
# processing entry 22900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_024437_959_LC16.png
# processing entry 23000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_024659_936_LC16.png
# processing entry 23100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_025025_957_LC16.png
# processing entry 23200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_025223_952_LC16.png
# processing entry 23300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_025552_983_LC16.png
# processing entry 23400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/PS201012/PR_20101120_025722_945_LC16.png
# processing campaign Batemans201011
# /Volumes/LZD1601/benthoz2015/Batemans201011/*.csv
# set(['CBOM', 'WA', 'BM', 'MAFR', 'MAEFB', 'MAFB', 'MAFG', 'CBFR', 'MALCB', 'SPH', 'SPM', 'CBBFA', 'SPC', 'SPE', 'MALCEK', 'MAAR', 'BIOTA', 'MAAG', 'MAS', 'SPES', 'SPEP', 'MAA', 'SPEL', 'SPMR', 'MAF', 'SPEB', 'CBNBU', 'SP', 'CRB', 'CSBRPD', 'MALAR', 'SCC', 'SCB', 'MALAB', 'MAEFR', 'MALA', 'CSE', 'CSF', 'CNCAC', 'S', 'CNCAZ', 'CBB', 'MA', 'CBE', 'BRYSF', 'CNTR', 'SPHT', 'SUP', 'SPHC', 'ASS', 'BRYH', 'MASB', 'ASC', 'WPO', 'MASR', 'BRYS', 'AUC', 'MAENG', 'MAENB', 'CNCA', 'AUS', 'MAENR', 'CS', 'UNK', 'MAEC', 'BRY', 'MAEF', 'CNHYD', 'CNHYC', 'SU', 'MAEN', 'CBBNA', 'BRYHF', 'SC', 'BRYHM', 'UNS', 'A', 'ESU', 'ESS', 'AS', 'AU', 'ESUR', 'SPMSI', 'MAECR', 'MAECB', 'MOCH'])
# Number of classes 86
# Testing...
# *** imclass CBOM
# /Volumes/LZD1601/training_data/benthoz_299patch/CBOM already present - Skipping making dir
# *** imclass WA
# /Volumes/LZD1601/training_data/benthoz_299patch/WA already present - Skipping making dir
# *** imclass BM
# /Volumes/LZD1601/training_data/benthoz_299patch/BM already present - Skipping making dir
# *** imclass MAFR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFR already present - Skipping making dir
# *** imclass MAEFB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEFB already present - Skipping making dir
# *** imclass MAFB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFB already present - Skipping making dir
# *** imclass MAFG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAFG already present - Skipping making dir
# *** imclass CBFR
# /Volumes/LZD1601/training_data/benthoz_299patch/CBFR already present - Skipping making dir
# *** imclass MALCB
# /Volumes/LZD1601/training_data/benthoz_299patch/MALCB already present - Skipping making dir
# *** imclass SPH
# /Volumes/LZD1601/training_data/benthoz_299patch/SPH already present - Skipping making dir
# *** imclass SPM
# /Volumes/LZD1601/training_data/benthoz_299patch/SPM already present - Skipping making dir
# *** imclass CBBFA
# /Volumes/LZD1601/training_data/benthoz_299patch/CBBFA already present - Skipping making dir
# *** imclass SPC
# /Volumes/LZD1601/training_data/benthoz_299patch/SPC already present - Skipping making dir
# *** imclass SPE
# /Volumes/LZD1601/training_data/benthoz_299patch/SPE already present - Skipping making dir
# *** imclass MALCEK
# /Volumes/LZD1601/training_data/benthoz_299patch/MALCEK already present - Skipping making dir
# *** imclass MAAR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAAR already present - Skipping making dir
# *** imclass BIOTA
# /Volumes/LZD1601/training_data/benthoz_299patch/BIOTA already present - Skipping making dir
# *** imclass MAAG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAAG already present - Skipping making dir
# *** imclass MAS
# /Volumes/LZD1601/training_data/benthoz_299patch/MAS already present - Skipping making dir
# *** imclass SPES
# /Volumes/LZD1601/training_data/benthoz_299patch/SPES already present - Skipping making dir
# *** imclass SPEP
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEP already present - Skipping making dir
# *** imclass MAA
# /Volumes/LZD1601/training_data/benthoz_299patch/MAA already present - Skipping making dir
# *** imclass SPEL
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEL already present - Skipping making dir
# *** imclass SPMR
# /Volumes/LZD1601/training_data/benthoz_299patch/SPMR already present - Skipping making dir
# *** imclass MAF
# /Volumes/LZD1601/training_data/benthoz_299patch/MAF already present - Skipping making dir
# *** imclass SPEB
# /Volumes/LZD1601/training_data/benthoz_299patch/SPEB already present - Skipping making dir
# *** imclass CBNBU
# /Volumes/LZD1601/training_data/benthoz_299patch/CBNBU already present - Skipping making dir
# *** imclass SP
# /Volumes/LZD1601/training_data/benthoz_299patch/SP already present - Skipping making dir
# *** imclass CRB
# /Volumes/LZD1601/training_data/benthoz_299patch/CRB already present - Skipping making dir
# *** imclass CSBRPD
# /Volumes/LZD1601/training_data/benthoz_299patch/CSBRPD already present - Skipping making dir
# *** imclass MALAR
# /Volumes/LZD1601/training_data/benthoz_299patch/MALAR already present - Skipping making dir
# *** imclass SCC
# /Volumes/LZD1601/training_data/benthoz_299patch/SCC already present - Skipping making dir
# *** imclass SCB
# /Volumes/LZD1601/training_data/benthoz_299patch/SCB already present - Skipping making dir
# *** imclass MALAB
# /Volumes/LZD1601/training_data/benthoz_299patch/MALAB already present - Skipping making dir
# *** imclass MAEFR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEFR already present - Skipping making dir
# *** imclass MALA
# /Volumes/LZD1601/training_data/benthoz_299patch/MALA already present - Skipping making dir
# *** imclass CSE
# /Volumes/LZD1601/training_data/benthoz_299patch/CSE already present - Skipping making dir
# *** imclass CSF
# /Volumes/LZD1601/training_data/benthoz_299patch/CSF already present - Skipping making dir
# *** imclass CNCAC
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCAC already present - Skipping making dir
# *** imclass S
# /Volumes/LZD1601/training_data/benthoz_299patch/S already present - Skipping making dir
# *** imclass CNCAZ
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCAZ already present - Skipping making dir
# *** imclass CBB
# /Volumes/LZD1601/training_data/benthoz_299patch/CBB already present - Skipping making dir
# *** imclass MA
# /Volumes/LZD1601/training_data/benthoz_299patch/MA already present - Skipping making dir
# *** imclass CBE
# /Volumes/LZD1601/training_data/benthoz_299patch/CBE already present - Skipping making dir
# *** imclass BRYSF
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYSF already present - Skipping making dir
# *** imclass CNTR
# /Volumes/LZD1601/training_data/benthoz_299patch/CNTR already present - Skipping making dir
# *** imclass SPHT
# /Volumes/LZD1601/training_data/benthoz_299patch/SPHT already present - Skipping making dir
# *** imclass SUP
# /Volumes/LZD1601/training_data/benthoz_299patch/SUP already present - Skipping making dir
# *** imclass SPHC
# /Volumes/LZD1601/training_data/benthoz_299patch/SPHC already present - Skipping making dir
# *** imclass ASS
# /Volumes/LZD1601/training_data/benthoz_299patch/ASS already present - Skipping making dir
# *** imclass BRYH
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYH already present - Skipping making dir
# *** imclass MASB
# /Volumes/LZD1601/training_data/benthoz_299patch/MASB already present - Skipping making dir
# *** imclass ASC
# /Volumes/LZD1601/training_data/benthoz_299patch/ASC already present - Skipping making dir
# *** imclass WPO
# /Volumes/LZD1601/training_data/benthoz_299patch/WPO already present - Skipping making dir
# *** imclass MASR
# /Volumes/LZD1601/training_data/benthoz_299patch/MASR already present - Skipping making dir
# *** imclass BRYS
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYS already present - Skipping making dir
# *** imclass AUC
# /Volumes/LZD1601/training_data/benthoz_299patch/AUC already present - Skipping making dir
# *** imclass MAENG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENG already present - Skipping making dir
# *** imclass MAENB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENB already present - Skipping making dir
# *** imclass CNCA
# /Volumes/LZD1601/training_data/benthoz_299patch/CNCA already present - Skipping making dir
# *** imclass AUS
# /Volumes/LZD1601/training_data/benthoz_299patch/AUS already present - Skipping making dir
# *** imclass MAENR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENR already present - Skipping making dir
# *** imclass CS
# /Volumes/LZD1601/training_data/benthoz_299patch/CS already present - Skipping making dir
# *** imclass UNK
# /Volumes/LZD1601/training_data/benthoz_299patch/UNK already present - Skipping making dir
# *** imclass MAEC
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEC already present - Skipping making dir
# *** imclass BRY
# /Volumes/LZD1601/training_data/benthoz_299patch/BRY already present - Skipping making dir
# *** imclass MAEF
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEF already present - Skipping making dir
# *** imclass CNHYD
# /Volumes/LZD1601/training_data/benthoz_299patch/CNHYD already present - Skipping making dir
# *** imclass CNHYC
# /Volumes/LZD1601/training_data/benthoz_299patch/CNHYC already present - Skipping making dir
# *** imclass SU
# /Volumes/LZD1601/training_data/benthoz_299patch/SU already present - Skipping making dir
# *** imclass MAEN
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEN already present - Skipping making dir
# *** imclass CBBNA
# /Volumes/LZD1601/training_data/benthoz_299patch/CBBNA already present - Skipping making dir
# *** imclass BRYHF
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYHF already present - Skipping making dir
# *** imclass SC
# /Volumes/LZD1601/training_data/benthoz_299patch/SC already present - Skipping making dir
# *** imclass BRYHM
# /Volumes/LZD1601/training_data/benthoz_299patch/BRYHM already present - Skipping making dir
# *** imclass UNS
# /Volumes/LZD1601/training_data/benthoz_299patch/UNS already present - Skipping making dir
# *** imclass A
# /Volumes/LZD1601/training_data/benthoz_299patch/A already present - Skipping making dir
# *** imclass ESU
# /Volumes/LZD1601/training_data/benthoz_299patch/ESU already present - Skipping making dir
# *** imclass ESS
# /Volumes/LZD1601/training_data/benthoz_299patch/ESS already present - Skipping making dir
# *** imclass AS
# /Volumes/LZD1601/training_data/benthoz_299patch/AS already present - Skipping making dir
# *** imclass AU
# /Volumes/LZD1601/training_data/benthoz_299patch/AU already present - Skipping making dir
# *** imclass ESUR
# /Volumes/LZD1601/training_data/benthoz_299patch/ESUR already present - Skipping making dir
# *** imclass SPMSI
# /Volumes/LZD1601/training_data/benthoz_299patch/SPMSI already present - Skipping making dir
# *** imclass MAECR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECR already present - Skipping making dir
# *** imclass MAECB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECB already present - Skipping making dir
# *** imclass MOCH
# /Volumes/LZD1601/training_data/benthoz_299patch/MOCH already present - Skipping making dir
# Number of images 939, number of entries 23475
# processing entry 0
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_014413_240_LC16.png
# processing entry 100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_014647_285_LC16.png
# processing entry 200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_022710_161_LC16.png
# processing entry 300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_022827_124_LC16.png
# processing entry 400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_015156_265_LC16.png
# processing entry 500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_015421_277_LC16.png
# processing entry 600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_015521_268_LC16.png
# processing entry 700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_015658_277_LC16.png
# processing entry 800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_020020_296_LC16.png
# processing entry 900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_020128_288_LC16.png
# processing entry 1000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_020200_297_LC16.png
# processing entry 1100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_024315_148_LC16.png
# processing entry 1200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_020602_311_LC16.png
# processing entry 1300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_020727_333_LC16.png
# processing entry 1400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_024810_153_LC16.png
# processing entry 1500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_021050_329_LC16.png
# processing entry 1600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101216_021218_336_LC16.png
# processing entry 1700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025145_155_LC16.png
# processing entry 1800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025403_165_LC16.png
# processing entry 1900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025508_194_LC16.png
# processing entry 2000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025632_160_LC16.png
# processing entry 2100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025706_184_LC16.png
# processing entry 2200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025833_166_LC16.png
# processing entry 2300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_025953_181_LC16.png
# processing entry 2400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_030143_165_LC16.png
# processing entry 2500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033029_525_LC16.png
# processing entry 2600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033119_479_LC16.png
# processing entry 2700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033237_504_LC16.png
# processing entry 2800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033416_508_LC16.png
# processing entry 2900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033708_522_LC16.png
# processing entry 3000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_212003_159_LC16.png
# processing entry 3100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_033938_526_LC16.png
# processing entry 3200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_212159_204_LC16.png
# processing entry 3300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_034113_547_LC16.png
# processing entry 3400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_212415_191_LC16.png
# processing entry 3500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_034354_544_LC16.png
# processing entry 3600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_032256_799_LC16.png
# processing entry 3700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_212657_209_LC16.png
# processing entry 3800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101219_034610_554_LC16.png
# processing entry 3900
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_212821_203_LC16.png
# processing entry 4000
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_213020_208_LC16.png
# processing entry 4100
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_032730_843_LC16.png
# processing entry 4200
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_213220_231_LC16.png
# processing entry 4300
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_032953_813_LC16.png
# processing entry 4400
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_033048_835_LC16.png
# processing entry 4500
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_213607_267_LC16.png
# processing entry 4600
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_213739_237_LC16.png
# processing entry 4700
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101217_033541_809_LC16.png
# processing entry 4800
# **** WARNING: could not find image /Volumes/LZD1601/benthoz2015/Batemans201011/PR_20101218_214041_300_LC16.png
# processing entry 4900
# ...
# processing entry 17500
# processing entry 17600
# processing entry 17700
# processing entry 17800
# processing entry 17900
# processing entry 18000
# processing entry 18100
# processing entry 18200
# processing entry 18300
# processing entry 18400
# processing entry 18500
# processing entry 18600
# processing entry 18700
# processing entry 18800
# processing entry 18900
# processing entry 19000
# processing entry 19100
# processing entry 19200
# processing entry 19300
# processing entry 19400
# processing entry 19500
# processing entry 19600
# processing entry 19700
# processing entry 19800
# processing entry 19900
# processing entry 20000
# processing entry 20100
# processing entry 20200
# processing entry 20300
# processing entry 20400
# processing entry 20500
# processing entry 20600
# processing entry 20700
# processing entry 20800
# processing entry 20900
# processing entry 21000
# processing entry 21100
# processing entry 21200
# processing entry 21300
# processing entry 21400
# processing entry 21500
# processing entry 21600
# processing entry 21700
# processing entry 21800
# processing entry 21900
# processing entry 22000
# processing entry 22100
# processing entry 22200
# processing entry 22300
# processing entry 22400
# processing entry 22500
# processing entry 22600
# processing entry 22700
# processing entry 22800
# processing entry 22900
# processing entry 23000
# processing entry 23100
# processing entry 23200
# processing entry 23300
# processing entry 23400
# processing entry 23500
# processing entry 23600
# processing entry 23700
# processing entry 23800
# processing entry 23900
# processing entry 24000
# processing entry 24100
# processing entry 24200
# processing entry 24300
# processing entry 24400
# processing entry 24500
# processing entry 24600
# processing entry 24700
# processing entry 24800
# processing entry 24900
# processing entry 25000
# processing entry 25100
# processing entry 25200
# processing entry 25300
# processing entry 25400
# processing entry 25500
# processing entry 25600
# processing entry 25700
# processing entry 25800
# processing entry 25900
# processing entry 26000
# processing entry 26100
# processing entry 26200
# processing entry 26300
# processing entry 26400
# processing entry 26500
# processing entry 26600
# processing entry 26700
# processing entry 26800
# processing entry 26900
# processing entry 27000
# processing entry 27100
# processing entry 27200
# processing entry 27300
# processing entry 27400
# processing entry 27500
# processing entry 27600
# processing entry 27700
# processing entry 27800
# processing entry 27900
# processing entry 28000
# processing entry 28100
# processing entry 28200
# processing entry 28300
# processing entry 28400
# processing entry 28500
# processing entry 28600
# processing entry 28700
# processing entry 28800
# processing entry 28900
# processing entry 29000
# processing entry 29100
# processing entry 29200
# processing entry 29300
# processing entry 29400
# processing entry 29500
# processing entry 29600
# processing entry 29700
# processing entry 29800
# processing entry 29900
# processing entry 30000
# processing entry 30100
# processing entry 30200
# processing entry 30300
# processing entry 30400
# processing entry 30500
# processing entry 30600
# processing entry 30700
# processing entry 30800
# processing entry 30900
# processing entry 31000
# processing entry 31100
# processing entry 31200
# processing entry 31300
# processing entry 31400
# processing entry 31500
# processing entry 31600
# processing entry 31700
# processing entry 31800
# processing entry 31900
# processing entry 32000
# processing entry 32100
# processing entry 32200
# processing entry 32300
# processing entry 32400
# processing entry 32500
# processing entry 32600
# processing entry 32700
# processing entry 32800
# processing entry 32900
# processing entry 33000
# processing entry 33100
# processing entry 33200
# processing entry 33300
# processing entry 33400
# processing entry 33500
# processing entry 33600
# processing entry 33700
# processing entry 33800
# processing entry 33900
# processing entry 34000
# processing entry 34100
# processing entry 34200
# processing entry 34300
# processing entry 34400
# processing entry 34500
# processing entry 34600
# processing entry 34700
# processing entry 34800
# processing entry 34900
# processing entry 35000
# processing entry 35100
# processing entry 35200
# processing entry 35300
# processing entry 35400
# processing entry 35500
# processing entry 35600
# processing entry 35700
# processing entry 35800
# processing entry 35900
# processing entry 36000
# processing entry 36100
# processing entry 36200
# processing entry 36300
# processing entry 36400
# processing entry 36500
# processing entry 36600
# processing entry 36700
# processing entry 36800
# processing entry 36900
# processing entry 37000
# processing entry 37100
# processing entry 37200
# processing entry 37300
# processing entry 37400
# processing entry 37500
# processing entry 37600
# processing entry 37700
# processing entry 37800
# processing entry 37900
# processing entry 38000
# processing entry 38100
# processing entry 38200
# processing entry 38300
# processing entry 38400
# processing entry 38500
# processing entry 38600
# processing entry 38700
# processing entry 38800
# processing entry 38900
# processing entry 39000
# processing entry 39100
# processing entry 39200
# processing entry 39300
# processing entry 39400
# processing entry 39500
# processing entry 39600
# processing entry 39700
# processing entry 39800
# processing entry 39900
# processing entry 40000
# processing entry 40100
# processing entry 40200
# processing entry 40300
# processing entry 40400
# processing entry 40500
# processing entry 40600
# processing entry 40700
# processing entry 40800
# processing entry 40900
# processing entry 41000
# processing entry 41100
# processing entry 41200
# processing entry 41300
# processing entry 41400
# processing entry 41500
# processing entry 41600
# processing entry 41700
# processing entry 41800
# processing entry 41900
# processing entry 42000
# processing entry 42100
# processing entry 42200
# processing entry 42300
# processing entry 42400
# processing entry 42500
# processing entry 42600
# processing entry 42700
# processing entry 42800
# processing entry 42900
# processing entry 43000
# processing entry 43100
# processing entry 43200
# processing entry 43300
# processing entry 43400
# processing entry 43500
# processing entry 43600
# processing entry 43700
# processing entry 43800
# processing entry 43900
# processing entry 44000
# processing entry 44100
# processing entry 44200
# processing entry 44300
# processing entry 44400
# processing entry 44500
# processing entry 44600
# processing entry 44700
# processing entry 44800
# processing entry 44900
# processing entry 45000
# processing entry 45100
# processing entry 45200
# processing entry 45300
# processing entry 45400
# processing entry 45500
# processing entry 45600
# processing entry 45700
# processing entry 45800
# processing entry 45900
# processing entry 46000
# processing entry 46100
# processing entry 46200
# processing entry 46300
# processing entry 46400
# processing entry 46500
# processing entry 46600
# processing entry 46700
# processing entry 46800
# processing entry 46900
# processing entry 47000
# processing entry 47100
# processing entry 47200
# processing entry 47300
# processing entry 47400
# processing entry 47500
# processing entry 47600
# processing entry 47700
# processing entry 47800
# processing entry 47900
# processing entry 48000
# processing entry 48100
# processing entry 48200
# processing entry 48300
# processing entry 48400
# processing entry 48500
# processing entry 48600
# processing entry 48700
# processing entry 48800
# processing entry 48900
# processing entry 49000
# processing entry 49100
# processing entry 49200
# processing entry 49300
# processing entry 49400
# processing entry 49500
# processing entry 49600
# processing entry 49700
# processing entry 49800
# processing entry 49900
# processing entry 50000
# processing entry 50100
# processing entry 50200
# processing entry 50300
# processing campaign WA201304
# /Volumes/LZD1601/benthoz2015/WA201304/*.csv
# set(['CSM', 'CSSU', 'SUS', 'MASG', 'MALCB', 'SUPBR', 'SCR', 'A', 'C', 'CSE', 'CB', 'MAAR', 'MAENR', 'CS', 'UNK', 'MA', 'BRY', 'SP', 'MAEN', 'MAECG', 'MAECB', 'MAF'])
# Number of classes 22
# Testing...
# *** imclass CSM
# /Volumes/LZD1601/training_data/benthoz_299patch/CSM already present - Skipping making dir
# *** imclass CSSU
# /Volumes/LZD1601/training_data/benthoz_299patch/CSSU already present - Skipping making dir
# *** imclass SUS
# /Volumes/LZD1601/training_data/benthoz_299patch/SUS already present - Skipping making dir
# *** imclass MASG
# /Volumes/LZD1601/training_data/benthoz_299patch/MASG already present - Skipping making dir
# *** imclass MALCB
# /Volumes/LZD1601/training_data/benthoz_299patch/MALCB already present - Skipping making dir
# *** imclass SUPBR
# /Volumes/LZD1601/training_data/benthoz_299patch/SUPBR already present - Skipping making dir
# *** imclass SCR
# /Volumes/LZD1601/training_data/benthoz_299patch/SCR already present - Skipping making dir
# *** imclass A
# /Volumes/LZD1601/training_data/benthoz_299patch/A already present - Skipping making dir
# *** imclass C
# /Volumes/LZD1601/training_data/benthoz_299patch/C already present - Skipping making dir
# *** imclass CSE
# /Volumes/LZD1601/training_data/benthoz_299patch/CSE already present - Skipping making dir
# *** imclass CB
# /Volumes/LZD1601/training_data/benthoz_299patch/CB already present - Skipping making dir
# *** imclass MAAR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAAR already present - Skipping making dir
# *** imclass MAENR
# /Volumes/LZD1601/training_data/benthoz_299patch/MAENR already present - Skipping making dir
# *** imclass CS
# /Volumes/LZD1601/training_data/benthoz_299patch/CS already present - Skipping making dir
# *** imclass UNK
# /Volumes/LZD1601/training_data/benthoz_299patch/UNK already present - Skipping making dir
# *** imclass MA
# /Volumes/LZD1601/training_data/benthoz_299patch/MA already present - Skipping making dir
# *** imclass BRY
# /Volumes/LZD1601/training_data/benthoz_299patch/BRY already present - Skipping making dir
# *** imclass SP
# /Volumes/LZD1601/training_data/benthoz_299patch/SP already present - Skipping making dir
# *** imclass MAEN
# /Volumes/LZD1601/training_data/benthoz_299patch/MAEN already present - Skipping making dir
# *** imclass MAECG
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECG already present - Skipping making dir
# *** imclass MAECB
# /Volumes/LZD1601/training_data/benthoz_299patch/MAECB already present - Skipping making dir
# *** imclass MAF
# /Volumes/LZD1601/training_data/benthoz_299patch/MAF already present - Skipping making dir
# Number of images 508, number of entries 25438
# processing entry 0
# processing entry 100
# processing entry 200
# processing entry 300
# processing entry 400
# processing entry 500
# processing entry 600
# processing entry 700
# processing entry 800
# processing entry 900
# processing entry 1000
# processing entry 1100
# processing entry 1200
# processing entry 1300
# processing entry 1400
# processing entry 1500
# processing entry 1600
# processing entry 1700
# processing entry 1800
# processing entry 1900
# processing entry 2000
# processing entry 2100
# processing entry 2200
# processing entry 2300
# processing entry 2400
# processing entry 2500
# processing entry 2600
# processing entry 2700
# processing entry 2800
# processing entry 2900
# processing entry 3000
# processing entry 3100
# processing entry 3200
# processing entry 3300
# processing entry 3400
# processing entry 3500
# processing entry 3600
# processing entry 3700
# processing entry 3800
# processing entry 3900
# processing entry 4000
# processing entry 4100
# processing entry 4200
# processing entry 4300
# processing entry 4400
# processing entry 4500
# processing entry 4600
# processing entry 4700
# processing entry 4800
# processing entry 4900
# processing entry 5000
# processing entry 5100
# processing entry 5200
# processing entry 5300
# processing entry 5400
# processing entry 5500
# processing entry 5600
# processing entry 5700
# processing entry 5800
# processing entry 5900
# processing entry 6000
# processing entry 6100
# processing entry 6200
# processing entry 6300
# processing entry 6400
# processing entry 6500
# processing entry 6600
# processing entry 6700
# processing entry 6800
# processing entry 6900
# processing entry 7000
# processing entry 7100
# processing entry 7200
# processing entry 7300
# processing entry 7400
# processing entry 7500
# processing entry 7600
# processing entry 7700
# processing entry 7800
# processing entry 7900
# processing entry 8000
# processing entry 8100
# processing entry 8200
# processing entry 8300
# processing entry 8400
# processing entry 8500
# processing entry 8600
# processing entry 8700
# processing entry 8800
# processing entry 8900
# processing entry 9000
# processing entry 9100
# processing entry 9200
# processing entry 9300
# processing entry 9400
# processing entry 9500
# processing entry 9600
# processing entry 9700
# processing entry 9800
# processing entry 9900
# processing entry 10000
# processing entry 10100
# processing entry 10200
# processing entry 10300
# processing entry 10400
# processing entry 10500
# processing entry 10600
# processing entry 10700
# processing entry 10800
# processing entry 10900
# processing entry 11000
# processing entry 11100
# processing entry 11200
# processing entry 11300
# processing entry 11400
# processing entry 11500
# processing entry 11600
# processing entry 11700
# processing entry 11800
# processing entry 11900
# processing entry 12000
# processing entry 12100
# processing entry 12200
# processing entry 12300
# processing entry 12400
# processing entry 12500
# processing entry 12600
# processing entry 12700
# processing entry 12800
# processing entry 12900
# processing entry 13000
# processing entry 13100
# processing entry 13200
# processing entry 13300
# processing entry 13400
# processing entry 13500
# processing entry 13600
# processing entry 13700
# processing entry 13800
# processing entry 13900
# processing entry 14000
# processing entry 14100
# processing entry 14200
# processing entry 14300
# processing entry 14400
# processing entry 14500
# processing entry 14600
# processing entry 14700
# processing entry 14800
# processing entry 14900
# processing entry 15000
# processing entry 15100
# processing entry 15200
# processing entry 15300
# processing entry 15400
# processing entry 15500
# processing entry 15600
# processing entry 15700
# processing entry 15800
# processing entry 15900
# processing entry 16000
# processing entry 16100
# processing entry 16200
# processing entry 16300
# processing entry 16400
# processing entry 16500
# processing entry 16600
# processing entry 16700
# processing entry 16800
# processing entry 16900
# processing entry 17000
# processing entry 17100
# processing entry 17200
# processing entry 17300
# processing entry 17400
# processing entry 17500
# processing entry 17600
# processing entry 17700
# processing entry 17800
# processing entry 17900
# processing entry 18000
# processing entry 18100
# processing entry 18200
# processing entry 18300
# processing entry 18400
# processing entry 18500
# processing entry 18600
# processing entry 18700
# processing entry 18800
# processing entry 18900
# processing entry 19000
# processing entry 19100
# processing entry 19200
# processing entry 19300
# processing entry 19400
# processing entry 19500
# processing entry 19600
# processing entry 19700
# processing entry 19800
# processing entry 19900
# processing entry 20000
# processing entry 20100
# processing entry 20200
# processing entry 20300
# processing entry 20400
# processing entry 20500
# processing entry 20600
# processing entry 20700
# processing entry 20800
# processing entry 20900
# processing entry 21000
# processing entry 21100
# processing entry 21200
# processing entry 21300
# processing entry 21400
# processing entry 21500
# processing entry 21600
# processing entry 21700
# processing entry 21800
# processing entry 21900
# processing entry 22000
# processing entry 22100
# processing entry 22200
# processing entry 22300
# processing entry 22400
# processing entry 22500
# processing entry 22600
# processing entry 22700
# processing entry 22800
# processing entry 22900
# processing entry 23000
# processing entry 23100
# processing entry 23200
# processing entry 23300
# processing entry 23400
# processing entry 23500
# processing entry 23600
# processing entry 23700
# processing entry 23800
# processing entry 23900
# processing entry 24000
# processing entry 24100
# processing entry 24200
# processing entry 24300
# processing entry 24400
# processing entry 24500
# processing entry 24600
# processing entry 24700
# processing entry 24800
# processing entry 24900
# processing entry 25000
# processing entry 25100
# processing entry 25200
# processing entry 25300
# processing entry 25400
