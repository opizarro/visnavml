# %% [markdown]
# preparing labels and imagery for use with tensorflow

# %%
# takes a set of images and labels and prepares a structure that can be fed into
# inception v3 (which can handle imagenet 2012 inputs)
# this involves
# finding the coordinates of labelled points and the corresponding image
#  cropping at most 299 x 299 pixels around each labeled point.
# storing each cropped image in directories named after the type of label
import pandas as pd
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import string
import glob
import random

# %matplotlib inline

# %%
#training_path = '/Users/opizarro/training_data/max-woodside'
#training_path = '/Volumes/LZD1601/training_data/ziggy_99patch_flips'
training_path = '/home/opizarro/data/training_data/ziggy_299patch_4rot'

def maybe_makedir(dirname, force=False):
  if os.path.isdir(dirname) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping making dir' % (dirname))
  else:
    print('Making dir %s.' % dirname)
    os.makedirs(dirname)
  return 

maybe_makedir(training_path)
# Out:
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot.

# %%
def save_patch(crop_image,imagename,x,y,halfsize,imlabel,training_path):
    # save cropped image in corresponding directory
    crop_name = imagename + '_' + str(x) + '_' + str(y) + '_' + str(halfsize) + '.jpg'
    fullcrop_name = os.path.join(training_path,imlabel,crop_name)
    #print "saving cropped image to " + fullcrop_name
    cv2.imwrite(fullcrop_name,crop_image)

def save_patch_4rot(crop_image,imagename,x,y,halfsize,imlabel,training_path):
    
    (h, w) = crop_image.shape[:2]
    center = (w / 2, h / 2)
    
    angles = [0,90,180,270]
    for angle in angles:
        M = cv2.getRotationMatrix2D(center, angle, 1.0)
        rotated = cv2.warpAffine(crop_image, M, (w, h))
        save_patch(rotated,imagename+'_'+str(angle),x,y,halfsize,imlabel,training_path)

# %%
# usinging Bewley's code in squidle repo
import sys 
import os
sys.path.append('/home/opizarro/git/visnavml/prep_survey_images')
import cpc

xdim = 1360
ydim = 1024
patchsize =299
halfsize = int((patchsize-1)/2)
padsize = halfsize

#ziggy_root = '/Volumes/LZD1601/AUV-2010_cpc_img'
#ziggy_root = '/Users/opizarro/AUV-2010_cpc_img'
ziggy_root = '/media/opizarro/LZD1601/AUV-2010_cpc_img'
#cp = cpc.CPCFolderParser(os.path.join(ziggy_root,'BB_site1sz_15-1'))
cp = cpc.CPCFolderParser(ziggy_root)
#cp.bigdf.head()
#print cp.image_list
#print cp.cpc_list
#print cp.bigdf['label_number']

# %% [markdown]
# premake the directories for the different labels

# %%
class_label_set = set(cp.bigdf['cpc_code'])
print class_label_set
class_label_list = list(class_label_set)
print('Number of classes %i') % len(class_label_list)
print('Testing...')
for imclass in class_label_list:
    #imclasses = string.split(imclass,':')
    #imclass_short = imclasses[0]
    #print('*** imclass %s shortened to %s') % (imclass, imclass_short)
    print('*** imclass %s') % imclass
    maybe_makedir(os.path.join(training_path, imclass))
# Out:
# set(['P', 'S', 'MF', 'PAD', 'SARG'])
# Number of classes 5
# Testing...
# *** imclass P
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot/P.
# *** imclass S
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot/S.
# *** imclass MF
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot/MF.
# *** imclass PAD
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot/PAD.
# *** imclass SARG
# Making dir /home/opizarro/data/training_data/ziggy_299patch_4rot/SARG.

# %%
def process_cpc(row):
#print row[1].fraction_from_image_left
    #print row[1]
    imagename = row[1].image_name
    image_location = row[1].folder
    prior_imagename = ''
    fullimagename = os.path.join(image_location,imagename+'.jpg')
    if os.path.isfile(fullimagename):
        if fullimagename != prior_imagename:
            image = cv2.imread(fullimagename)
            reflect101 = cv2.copyMakeBorder(image,padsize,padsize,padsize,padsize,cv2.BORDER_REFLECT_101)
            prior_imagename = fullimagename
            
        imlabel = row[1].cpc_code    
        # find centre points
        
        x = int(round(row[1].fraction_from_image_left*(xdim-1))+padsize)
        y = int(round(row[1].fraction_from_image_top*(ydim-1))+padsize)
        
        # check dimensions correpond
        if xdim != image.shape[1] or ydim !=image.shape[0]:
            print('WARNING: actual image size and size in database not consistent')
    
        # crop around centre point
        #dx = min(min(x,halfsize),min(halfsize,xdim-x));
        #dy = min(min(y,halfsize),min(halfsize,ydim-y));
        #hs = min(dx,dy)
        hs = halfsize
        # at least 81 pixels across to have some context
        if hs == halfsize : 
            crop_image = reflect101[y-hs:y+hs+1, x-hs:x+hs+1]
        
            # generate rotated versions
            # save with unique name
        
            # save cropped image in corresponding director
            #crop_name = imagename + '_' + str(x) + '_' + str(y) + '_' + str(halfsize) + '.jpg'
            #fullcrop_name = os.path.join(training_path,imlabel,crop_name)
            #cv2.imwrite(fullcrop_name,crop_image)
            save_patch_4rot(crop_image,imagename,x,y,halfsize,imlabel,training_path) 
            #crop_im_fliplr = cv2.flip(crop_image,1)
            #save_patch_4rot(crop_im_fliplr,imagename+'_lr',x,y,halfsize,imlabel,training_path)
            
            cutstr =  ('this dot %s has label %s') % (imagename, imlabel)
            titstr =  ('x %i, y %i, xdim %i, ydim %i, hs %i') % (x,y,xdim,ydim,hs)
            
            if 0:
                plt.figure(1)
                plt.imshow(image)
                plt.title(titstr)
                plt.show()
                plt.figure(2)
                plt.imshow(crop_image)
                plt.title(cutstr)
                plt.show()
            
            #if counter%100 == 0:
            if (random.random() < 0.001):
                print("processing " + fullimagename)
                   # print("processing entry " + str(counter) + "\r")
        else:
          #  print("entry " + str(counter) + " Patch too small! " + str(hs) + " half size \r" )
            # print("Patch too small! " + str(hs) + " half size \r" )
            pass   
    else:
        #if row[0]%100 == 0:
       # print("PROBLEM processing entry " + str(counter) + "\r")
        print('**** WARNING: could not find image %s') % fullimagename

# %%
from joblib import Parallel, delayed
import multiprocessing

num_cores = multiprocessing.cpu_count()

#for row in cp.bigdf.iterrows():
#    process_cpc(row)
results = Parallel(n_jobs=num_cores)(delayed(process_cpc)(row) for row in cp.bigdf.iterrows())            
    
# add weblocation (basename)
#
# Out:
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_042204_688_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_042216_716_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_042507_673_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_043944_699_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_044136_728_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_044551_701_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site1sz_15-1/PR_20101121_044830_699_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-2/PR_20101120_232744_622_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-2/PR_20101120_232846_642_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-2/PR_20101120_232859_632_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-2/PR_20101120_233523_635_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-2/PR_20101120_234109_670_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_001749_660_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_002255_642_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_002525_689_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_002735_651_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_003512_651_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site2guz_14-3/PR_20101121_004018_676_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_194419_786_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_194658_784_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_194722_807_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_195243_789_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_195452_824_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-1/PR_20101120_200302_778_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_202523_830_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_202909_793_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_203857_824_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_203922_806_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_203939_810_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_204245_799_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_204904_821_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site3guz_13-2/PR_20101120_205127_802_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-1/PR_20101122_193633_644_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-2/PR_20101122_201530_666_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-2/PR_20101122_202634_671_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-3/PR_20101122_203955_701_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-3/PR_20101122_204035_701_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site4sz_17-3/PR_20101122_210710_703_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-1/PR_20101120_022428_944_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-1/PR_20101120_022449_947_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-1/PR_20101120_023800_949_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-1/PR_20101120_024319_948_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-1/PR_20101120_025324_942_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-2/PR_20101120_012227_620_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-2/PR_20101120_013137_192_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-2/PR_20101120_014832_192_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-2/PR_20101120_014955_181_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_004559_631_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_004828_592_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_004920_580_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_005309_621_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_005638_602_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_005805_600_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_010335_608_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_site5sz_12-3/PR_20101120_010347_613_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_GUZ_1_fingal06/PR_20101217_013629_797_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_GUZ_2_br10/PR_20101218_221633_457_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_SZ_1_fingal04/PR_20101216_034243_512_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_SZ_2_fingal04/PR_20101216_030655_698_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_1-3-1/PR_20101117_002500_667_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_1-3-1/PR_20101117_003300_671_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_1-3-2/PR_20101117_005100_669_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_1-3-2/PR_20101117_005900_690_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-9-1/PR_20101118_062001_907_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-9-1/PR_20101118_062101_921_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-18-2/PR_20101122_230947_354_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-18-2/PR_20101122_233147_380_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-18-3/PR_20101122_222547_350_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-18-3/PR_20101122_223347_350_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_4-18-3/PR_20101122_225347_376_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-6-1/PR_20101117_225014_883_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-6-1/PR_20101117_225314_880_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-6-1/PR_20101117_230014_887_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-6-1/PR_20101117_230214_871_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-6-1/PR_20101117_233114_896_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-8-2/PR_20101118_021650_775_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-8-2/PR_20101118_021750_732_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-8-3/PR_20101118_011050_750_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-8-3/PR_20101118_011150_708_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/BB_6-8-3/PR_20101118_012650_756_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b9-1/PR_20101218_051541_288_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b9-2/PR_20101218_045401_156_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-1/PR_20101219_000339_522_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-1/PR_20101219_002739_628_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_005319_728_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_005419_772_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_005819_764_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_010119_777_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_010519_781_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_011119_807_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_011719_847_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_011819_879_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-2/PR_20101219_011819_879_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_b11-3/PR_20101219_015220_001_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-1/PR_20101215_201423_462_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-1/PR_20101215_202823_502_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-2/PR_20101215_204823_579_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-2/PR_20101215_210323_647_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-3/PR_20101215_214123_787_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/PS_f3-3/PR_20101215_221903_929_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henNtr2/PR_20101022_012800_620_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr1/PR_20101021_064400_486_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr2/PR_20101021_065200_826_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr2/PR_20101021_070300_606_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr2/PR_20101021_070800_519_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr2/PR_20101021_071300_918_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr3/PR_20101021_071700_847_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henStr3/PR_20101021_073100_064_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b1/PR_20101023_055300_100_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b1/PR_20101023_060740_250_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b1/PR_20101023_060920_293_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_064040_584_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_064320_610_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_064440_643_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_064800_675_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_065740_742_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b2/PR_20101023_065900_745_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_073340_972_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_073600_016_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_073820_029_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_074140_055_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_074800_091_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_074840_096_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_075520_149_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN9b3/PR_20101023_075900_191_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN13-7-1/PR_20101022_053959_324_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN13-7-1/PR_20101022_054150_335_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN13-7-1/PR_20101022_054959_412_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN13-7-1/PR_20101022_060159_496_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN13-7-1/PR_20101022_060230_496_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN132/PR_20101024_080430_319_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN132/PR_20101024_080515_365_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN132/PR_20101024_081845_472_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN132/PR_20101024_082045_519_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN133/PR_20101024_084030_645_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN133/PR_20101024_084045_663_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN133/PR_20101024_085600_782_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henN133/PR_20101024_085930_819_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS111/PR_20101024_000025_963_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS111/PR_20101024_000035_951_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS111/PR_20101024_000615_992_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS111/PR_20101024_000800_009_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_001900_156_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_002020_142_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_002200_158_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_002340_174_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_002520_177_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_003400_274_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_004140_349_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_004220_382_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS112/PR_20101024_004600_377_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS113/PR_20101024_010100_536_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS113/PR_20101024_010100_536_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS113/PR_20101024_010820_634_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS113/PR_20101024_011620_684_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS113/PR_20101024_011820_704_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS121/PR_20101024_021000_428_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS121/PR_20101024_021540_487_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS121/PR_20101024_022420_554_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS121/PR_20101024_022720_596_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS121/PR_20101024_022800_602_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS122/PR_20101024_024740_779_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS122/PR_20101024_025000_815_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS122/PR_20101024_030400_981_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS122/PR_20101024_031040_012_LC16.jpg
# processing /media/opizarro/LZD1601/AUV-2010_cpc_img/henS122/PR_20101024_031300_034_LC16.jpg
