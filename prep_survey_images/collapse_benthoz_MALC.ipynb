# %% [markdown]
# preparing labels and imagery for use with tensorflow

# %%
# create a collapsed version of classes

import os

import string
import glob
import random
import shutil

def maybe_makedir(dirname, force=False):
  if os.path.isdir(dirname) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping making dir' % (dirname))
  else:
    print('Making dir %s.' % dirname)
    os.makedirs(dirname)
  return

# %%
original_classes = '/Volumes/LZD1601/training_data/benthoz_99patch_flips'
#collapsed_classes = '/Volumes/LZD1601/training_data_kelpnokelp/benthoz2015_99patch_flips'
#balanced_classes = '/Volumes/LZD1601/training_data_kelpnokelp/benthoz2015_99patch_flips_balanced'
collapsed_classes = '/Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips'
balanced_classes = '/Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips_balanced'

# %%
# number of classes
catalog = list()
for path, dirs, files in os.walk(original_classes):
    
    #print  path, " has ", 
    #print  len(dirs), " dirs ",
    #print  " and ", len(files) , " files"
    if len(dirs)==0:
        catalog.append({'class': os.path.basename(path), 'examples': len(files)})
        print catalog[-1]
# Out:
# {'class': 'CBOM', 'examples': 640}
# {'class': 'WA', 'examples': 8}
# {'class': 'BM', 'examples': 40}
# {'class': 'MAFR', 'examples': 1792}
# {'class': 'MAEFB', 'examples': 440}
# {'class': 'MAFB', 'examples': 1920}
# {'class': 'MAFG', 'examples': 152}
# {'class': 'CBFR', 'examples': 104}
# {'class': 'MALCB', 'examples': 141152}
# {'class': 'SPH', 'examples': 408}
# {'class': 'SPM', 'examples': 5256}
# {'class': 'CBBFA', 'examples': 2384}
# {'class': 'SPC', 'examples': 24040}
# {'class': 'SPE', 'examples': 168}
# {'class': 'MALCEK', 'examples': 15432}
# {'class': 'MAAR', 'examples': 1216}
# {'class': 'BIOTA', 'examples': 118992}
# {'class': 'MAAG', 'examples': 8}
# {'class': 'MAS', 'examples': 32}
# {'class': 'SPES', 'examples': 656}
# {'class': 'SPEP', 'examples': 648}
# {'class': 'MAA', 'examples': 144}
# {'class': 'SPEL', 'examples': 4744}
# {'class': 'SPMR', 'examples': 472}
# {'class': 'MAF', 'examples': 11808}
# {'class': 'SPEB', 'examples': 7568}
# {'class': 'CBNBU', 'examples': 96}
# {'class': 'SP', 'examples': 1824}
# {'class': 'CRB', 'examples': 16}
# {'class': 'CSBRPD', 'examples': 0}
# {'class': 'MALAR', 'examples': 2944}
# {'class': 'SCC', 'examples': 392}
# {'class': 'SCB', 'examples': 240}
# {'class': 'MALAB', 'examples': 176}
# {'class': 'MAEFR', 'examples': 19432}
# {'class': 'MALA', 'examples': 296}
# {'class': 'CSE', 'examples': 3072}
# {'class': 'CSF', 'examples': 192}
# {'class': 'CNCAC', 'examples': 272}
# {'class': 'S', 'examples': 160}
# {'class': 'CNCAZ', 'examples': 2488}
# {'class': 'CBB', 'examples': 80}
# {'class': 'MA', 'examples': 219736}
# {'class': 'CBE', 'examples': 352}
# {'class': 'BRYSF', 'examples': 1320}
# {'class': 'CNTR', 'examples': 24}
# {'class': 'SPHT', 'examples': 1000}
# {'class': 'SUP', 'examples': 10856}
# {'class': 'SPHC', 'examples': 4744}
# {'class': 'ASS', 'examples': 128}
# {'class': 'BRYH', 'examples': 360}
# {'class': 'MASB', 'examples': 8}
# {'class': 'ASC', 'examples': 8}
# {'class': 'WPO', 'examples': 8}
# {'class': 'MASR', 'examples': 8}
# {'class': 'BRYS', 'examples': 3472}
# {'class': 'AUC', 'examples': 360}
# {'class': 'MAENG', 'examples': 4360}
# {'class': 'MAENB', 'examples': 1704}
# {'class': 'CNCA', 'examples': 16}
# {'class': 'AUS', 'examples': 1160}
# {'class': 'MAENR', 'examples': 93864}
# {'class': 'CS', 'examples': 752}
# {'class': 'UNK', 'examples': 2104}
# {'class': 'MAEC', 'examples': 528}
# {'class': 'BRY', 'examples': 112}
# {'class': 'MAEF', 'examples': 4600}
# {'class': 'CNHYD', 'examples': 1240}
# {'class': 'CNHYC', 'examples': 336}
# {'class': 'SU', 'examples': 105272}
# {'class': 'MAEN', 'examples': 18856}
# {'class': 'CBBNA', 'examples': 568}
# {'class': 'BRYHF', 'examples': 232}
# {'class': 'SC', 'examples': 968}
# {'class': 'BRYHM', 'examples': 8}
# {'class': 'UNS', 'examples': 12224}
# {'class': 'A', 'examples': 152}
# {'class': 'ESU', 'examples': 224}
# {'class': 'ESS', 'examples': 96}
# {'class': 'AS', 'examples': 232}
# {'class': 'AU', 'examples': 160}
# {'class': 'ESUR', 'examples': 360}
# {'class': 'SPMSI', 'examples': 16800}
# {'class': 'MAECR', 'examples': 216}
# {'class': 'MAECB', 'examples': 1992}
# {'class': 'MOCH', 'examples': 24}
# {'class': 'CR', 'examples': 8}
# {'class': 'CBFF', 'examples': 1168}
# {'class': 'CSAC', 'examples': 8}
# {'class': 'CBNBC', 'examples': 16}
# {'class': 'CBNBS', 'examples': 8}
# {'class': 'MAEFG', 'examples': 128}
# {'class': 'MALAG', 'examples': 64}
# {'class': 'CSM', 'examples': 104}
# {'class': 'C', 'examples': 680}
# {'class': 'CBNB', 'examples': 8}
# {'class': 'EFU', 'examples': 1224}
# {'class': 'CST', 'examples': 360}
# {'class': 'CNTFT', 'examples': 8}
# {'class': 'CBF', 'examples': 624}
# {'class': 'BRYSD', 'examples': 32}
# {'class': 'ESC', 'examples': 16}
# {'class': 'CBBFM', 'examples': 376}
# {'class': 'CBFFS', 'examples': 176}
# {'class': 'CBFFC', 'examples': 4384}
# {'class': 'CBBN', 'examples': 64}
# {'class': 'CBBF', 'examples': 48}
# {'class': 'WPE', 'examples': 0}
# {'class': 'CB', 'examples': 32}
# {'class': 'BRYHE', 'examples': 8}
# {'class': 'ESURCR', 'examples': 16}
# {'class': 'CSSU', 'examples': 288}
# {'class': 'CSSO', 'examples': 8}
# {'class': 'SCR', 'examples': 8304}
# {'class': 'CBW', 'examples': 1368}
# {'class': 'E', 'examples': 16}
# {'class': 'CNTU', 'examples': 80}
# {'class': 'MAECG', 'examples': 568}
# {'class': 'FB', 'examples': 8}
# {'class': 'SUS', 'examples': 225438}
# {'class': 'SEAG', 'examples': 136}
# {'class': 'SUPBR', 'examples': 168}
# {'class': 'CSBR', 'examples': 16}
# {'class': 'CSCOR', 'examples': 72}
# {'class': 'CSSOA', 'examples': 264}
# {'class': 'SPMST', 'examples': 72}
# {'class': 'MASG', 'examples': 8}
# {'class': 'MOG', 'examples': 13056}
# {'class': 'WPOT', 'examples': 96}
# {'class': 'F', 'examples': 256}
# {'class': 'SPMB', 'examples': 328}
# {'class': 'SPMC', 'examples': 8}
# {'class': 'SPCE', 'examples': 5824}
# {'class': 'MO', 'examples': 24}
# {'class': 'SPCC', 'examples': 576}
# {'class': 'EOBSS', 'examples': 56}
# {'class': 'SUPB', 'examples': 7416}
# {'class': 'BI', 'examples': 368}
# {'class': 'WF', 'examples': 0}
# {'class': 'JCT', 'examples': 0}
# {'class': 'CBQ', 'examples': 0}
# {'class': 'MALC', 'examples': 0}
# {'class': 'CN', 'examples': 0}
# {'class': 'NOI', 'examples': 0}
# {'class': 'MOB', 'examples': 8}

# %%
min_examples = 500
max_examples = 2000
usable_classes = 0
for entry in catalog:
    if entry['examples'] > min_examples:
        print entry
        usable_classes = usable_classes+1
print('classes with more than %i examples: %i') % (min_examples,usable_classes)
# Out:
# {'class': 'CBOM', 'examples': 640}
# {'class': 'MAFR', 'examples': 1792}
# {'class': 'MAFB', 'examples': 1920}
# {'class': 'MALCB', 'examples': 141152}
# {'class': 'SPM', 'examples': 5256}
# {'class': 'CBBFA', 'examples': 2384}
# {'class': 'SPC', 'examples': 24040}
# {'class': 'MALCEK', 'examples': 15432}
# {'class': 'MAAR', 'examples': 1216}
# {'class': 'BIOTA', 'examples': 118992}
# {'class': 'SPES', 'examples': 656}
# {'class': 'SPEP', 'examples': 648}
# {'class': 'SPEL', 'examples': 4744}
# {'class': 'MAF', 'examples': 11808}
# {'class': 'SPEB', 'examples': 7568}
# {'class': 'SP', 'examples': 1824}
# {'class': 'MALAR', 'examples': 2944}
# {'class': 'MAEFR', 'examples': 19432}
# {'class': 'CSE', 'examples': 3072}
# {'class': 'CNCAZ', 'examples': 2488}
# {'class': 'MA', 'examples': 219736}
# {'class': 'BRYSF', 'examples': 1320}
# {'class': 'SPHT', 'examples': 1000}
# {'class': 'SUP', 'examples': 10856}
# {'class': 'SPHC', 'examples': 4744}
# {'class': 'BRYS', 'examples': 3472}
# {'class': 'MAENG', 'examples': 4360}
# {'class': 'MAENB', 'examples': 1704}
# {'class': 'AUS', 'examples': 1160}
# {'class': 'MAENR', 'examples': 93864}
# {'class': 'CS', 'examples': 752}
# {'class': 'UNK', 'examples': 2104}
# {'class': 'MAEC', 'examples': 528}
# {'class': 'MAEF', 'examples': 4600}
# {'class': 'CNHYD', 'examples': 1240}
# {'class': 'SU', 'examples': 105272}
# {'class': 'MAEN', 'examples': 18856}
# {'class': 'CBBNA', 'examples': 568}
# {'class': 'SC', 'examples': 968}
# {'class': 'UNS', 'examples': 12224}
# {'class': 'SPMSI', 'examples': 16800}
# {'class': 'MAECB', 'examples': 1992}
# {'class': 'CBFF', 'examples': 1168}
# {'class': 'C', 'examples': 680}
# {'class': 'EFU', 'examples': 1224}
# {'class': 'CBF', 'examples': 624}
# {'class': 'CBFFC', 'examples': 4384}
# {'class': 'SCR', 'examples': 8304}
# {'class': 'CBW', 'examples': 1368}
# {'class': 'MAECG', 'examples': 568}
# {'class': 'SUS', 'examples': 225438}
# {'class': 'MOG', 'examples': 13056}
# {'class': 'SPCE', 'examples': 5824}
# {'class': 'SPCC', 'examples': 576}
# {'class': 'SUPB', 'examples': 7416}
# classes with more than 500 examples: 55

# %%
#for path, dirs, files in os.walk(original_classes):
#    if len(dirs)==0:
dirs ={}
path ={}
files={}
for class_name in os.listdir(original_classes):
    if 1:
        
        # no sub directories means it's a class folder with only files
        #num_examples = len(files)
        ##class_name = os.path.basename(path)
        #print  class_name, " has ", 
        #print  " and ", num_examples , " files"
        if 0:#'MALC' in class_name:
            print('Class {} belongs to MALC'.format(class_name))
            files = os.listdir(os.path.join(original_classes,class_name))
            symfiles = files
            print("Linking %i images") % len(symfiles)
            destination = os.path.join(collapsed_classes,"MALC")
            maybe_makedir(destination)
            for entry in symfiles:
                destination_file = os.path.join(destination,os.path.basename(entry))
                source_file = os.path.join(original_classes,class_name,os.path.basename(entry))
                #os.symlink(source_file,destination_file)
                shutil.copyfile(source_file,destination_file)
            
        elif any(x in class_name for x in ['SUS']):
            print('Class {} in not MALC'.format(class_name))
            files = os.listdir(os.path.join(original_classes,class_name))
            symfiles = files
            print("Linking %i images") % len(symfiles)
            destination = os.path.join(collapsed_classes,"NotMALC")
            maybe_makedir(destination)
            for entry in symfiles:
                destination_file = os.path.join(destination,os.path.basename(entry))
                source_file = os.path.join(original_classes,class_name,os.path.basename(entry))
                #os.symlink(source_file,destination_file)
                shutil.copyfile(source_file,destination_file)
        else:
            print('skipping {}'.format(class_name))
            
            
            
       # if num_examples >= min_examples:
       #     print('using class %s with %i examples') % (class_name, num_examples)
       #     # can be used
       #     if num_examples >= max_examples:
       #         # sumsample before symlink
       #         symfiles = random.sample(files,max_examples)
       #     else:
       #         symfiles = files
       #     print("Linking %i images") % len(symfiles)
       #     destination = os.path.join(collapsed_classes,class_name)
       #     maybe_makedir(destination)
       #     for entry in symfiles:
       #         destination_file = os.path.join(destination,entry)
       #         source_file = os.path.join(path,entry)
       #         os.symlink(source_file,destination_file)
       # else:
       #     print('* skipping class %s with %i examples') % (class_name, num_examples)
# Out:
# skipping CBOM
# skipping WA
# skipping BM
# skipping MAFR
# skipping MAEFB
# skipping MAFB
# skipping MAFG
# skipping CBFR
# skipping MALCB
# skipping SPH
# skipping SPM
# skipping CBBFA
# skipping SPC
# skipping SPE
# skipping MALCEK
# skipping MAAR
# skipping BIOTA
# skipping MAAG
# skipping MAS
# skipping SPES
# skipping SPEP
# skipping MAA
# skipping SPEL
# skipping SPMR
# skipping MAF
# skipping SPEB
# skipping CBNBU
# skipping SP
# skipping CRB
# skipping CSBRPD
# skipping MALAR
# skipping SCC
# skipping SCB
# skipping MALAB
# skipping MAEFR
# skipping MALA
# skipping CSE
# skipping CSF
# skipping CNCAC
# skipping S
# skipping CNCAZ
# skipping CBB
# skipping MA
# skipping CBE
# skipping BRYSF
# skipping CNTR
# skipping SPHT
# skipping SUP
# skipping SPHC
# skipping ASS
# skipping BRYH
# skipping MASB
# skipping ASC
# skipping WPO
# skipping MASR
# skipping BRYS
# skipping AUC
# skipping MAENG
# skipping MAENB
# skipping CNCA
# skipping AUS
# skipping MAENR
# skipping CS
# skipping UNK
# skipping MAEC
# skipping BRY
# skipping MAEF
# skipping CNHYD
# skipping CNHYC
# skipping SU
# skipping MAEN
# skipping CBBNA
# skipping BRYHF
# skipping SC
# skipping BRYHM
# skipping UNS
# skipping A
# skipping ESU
# skipping ESS
# skipping AS
# skipping AU
# skipping ESUR
# skipping SPMSI
# skipping MAECR
# skipping MAECB
# skipping MOCH
# skipping CR
# skipping CBFF
# skipping CSAC
# skipping CBNBC
# skipping CBNBS
# skipping MAEFG
# skipping MALAG
# skipping CSM
# skipping C
# skipping CBNB
# skipping EFU
# skipping CST
# skipping CNTFT
# skipping CBF
# skipping BRYSD
# skipping ESC
# skipping CBBFM
# skipping CBFFS
# skipping CBFFC
# skipping CBBN
# skipping CBBF
# skipping WPE
# skipping CB
# skipping BRYHE
# skipping ESURCR
# skipping CSSU
# skipping CSSO
# skipping SCR
# skipping CBW
# skipping E
# skipping CNTU
# skipping MAECG
# skipping FB
# Class SUS in not MALC
# Linking 225659 images
# /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips/NotMALC already present - Skipping making dir
# skipping SEAG
# skipping SUPBR
# skipping CSBR
# skipping CSCOR
# skipping CSSOA
# skipping SPMST
# skipping MASG
# skipping MOG
# skipping WPOT
# skipping F
# skipping SPMB
# skipping SPMC
# skipping SPCE
# skipping MO
# skipping SPCC
# skipping EOBSS
# skipping SUPB
# skipping BI
# skipping WF
# skipping JCT
# skipping CBQ
# skipping MALC
# skipping CN
# skipping NOI
# skipping MOB

# %%
min_examples = 100000
max_examples = 200000
for path, dirs, files in os.walk(collapsed_classes):
    print('path {}').format(path)
    print('dirs {}').format(dirs)
    if len(dirs)==0:
        # no sub directories means it's a class folder with only files
        
        class_name = os.path.basename(path)
        print  class_name, " has ", 
        num_examples = len(files)
        print  " and ", num_examples , " files"
        if num_examples >= min_examples:
            print('using class %s with %i examples') % (class_name, num_examples)
            # can be used
            if num_examples >= max_examples:
                # sumsample before symlink
                symfiles = random.sample(files,max_examples)
            else:
                symfiles = files
            print("Linking %i images") % len(symfiles)
            destination = os.path.join(balanced_classes,class_name)
            maybe_makedir(destination)
            for entry in symfiles:
                destination_file = os.path.join(destination,entry)
                source_file = os.path.join(path,entry)
                os.symlink(source_file,destination_file)
        else:
            print('* skipping class %s with %i examples') % (class_name, num_examples)
# Out:
# path /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips
# dirs ['MALC', 'NotMALC']
# path /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips/MALC
# dirs []
# MALC  has   and  162968  files
# using class MALC with 162968 examples
# Linking 162968 images
# Making dir /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips_balanced/MALC.
# path /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips/NotMALC
# dirs []
# NotMALC  has   and  1007010  files
# using class NotMALC with 1007010 examples
# Linking 200000 images
# Making dir /Users/opizarro/training_data_kelpnokelp/benthoz_99patch_flips_balanced/NotMALC.
